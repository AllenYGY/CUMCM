# %% [markdown]
# # 时间序列预测批发价

# %%
import pandas as pd

# 读取数据
data = pd.read_excel('Q3-1.xlsx')

# 将销售日期列转换为日期数据类型
data['销售日期'] = pd.to_datetime(data['销售日期'])

# 按单品名称拆分数据
unique_products = data['单品名称'].unique()
product_forecasts = []

for product_name in unique_products:
    # 提取单品销售数据
    product_df = data[data['单品名称'] == product_name][['销售日期', '批发价格(元/千克)']]
    product_df.set_index('销售日期', inplace=True)
    
    # 获取最后一天的销量
    last_day_sales = product_df.iloc[-1]['批发价格(元/千克)']
    
    # 创建包含预测结果的DataFrame
    forecast_df = pd.DataFrame({
        '销售日期': ['2023-07-01'],
        '单品名称': [product_name],
        '批发价格(元/千克)': [last_day_sales]  # 将最后一天的销量作为预测结果
    })
    
    # 将预测结果添加到列表
    product_forecasts.append(forecast_df)

# 将所有预测结果合并成一个新的DataFrame
final_forecast_df = pd.concat(product_forecasts)

# 保存新的DataFrame到Excel文件
final_forecast_df.to_excel('product_forecasts.xlsx', index=False)

# %% [markdown]
# # 时间序列预测销量

# %%
import pandas as pd

# 读取数据
data = pd.read_excel('Q3-1.xlsx')

# 将销售日期列转换为日期数据类型
data['销售日期'] = pd.to_datetime(data['销售日期'])

# 按单品名称拆分数据
unique_products = data['单品名称'].unique()
product_forecasts = []

for product_name in unique_products:
    # 提取单品销售数据
    product_df = data[data['单品名称'] == product_name][['销售日期', '销量(千克)']]
    product_df.set_index('销售日期', inplace=True)
    
    # 获取最后一天的销量
    last_day_sales = product_df.iloc[-1]['销量(千克)']
    
    # 创建包含预测结果的DataFrame
    forecast_df = pd.DataFrame({
        '销售日期': ['2023-07-01'],
        '单品名称': [product_name],
        '销量(千克)': [last_day_sales]  # 将最后一天的销量作为预测结果
    })
    
    # 将预测结果添加到列表
    product_forecasts.append(forecast_df)

# 将所有预测结果合并成一个新的DataFrame
final_forecast_df = pd.concat(product_forecasts)

# 保存新的DataFrame到Excel文件
final_forecast_df.to_excel('product_sales.xlsx', index=False)

# %% [markdown]
# # 得到单品售价与销售量的关系

# %%
import pandas as pd

# 读取数据
data = pd.read_excel('Q3-1.xlsx')

# 定义阈值
threshold = 30

# 计算每个单品名称的行数
product_counts = data['单品名称'].value_counts()

# 获取满足条件的单品名称列表
valid_products = product_counts[product_counts >= threshold].index.tolist()

# 根据条件筛选数据
filtered_data = data[data['单品名称'].isin(valid_products)]

# 打印筛选后的数据
filtered_data.to_excel('Q3-2.xlsx', index=False)

# %%
# 读取数据
data = pd.read_excel('Q3-2.xlsx')

# 计算每个品类的销量的异常值阈值（可以根据具体需求选择不同的方法，如Z-score或IQR）
# 这里以Z-score为例
def remove_outliers(group):
    group['Z_score'] = (group['销量(千克)'] - group['销量(千克)'].mean()) / group['销量(千克)'].std()
    return group[group['Z_score'].abs() <= 3]  # 3是一个常用的阈值，你可以根据需要调整

filtered_data = data.groupby('单品名称').apply(remove_outliers)
filtered_data
filtered_data.to_excel('Q3-2.xlsx', index=False)

# %%
import pandas as pd
from pulp import LpVariable, LpProblem, LpMinimize, LpStatus, value
from sklearn.metrics import r2_score

# 从Excel文件读取数据
data = pd.read_excel('Q3-2.xlsx')
groups = data.groupby("单品名称")

results = []  # Initialize an empty list to store results

def getRsquared(A, B, C, price, wholesale_price, quantity):
    # 获取线性规划模型的结果
    A_value = value(A)
    B_value = value(B)
    C_value = value(C)

    # 使用线性规划模型的结果进行预测
    predicted_price = [A_value * q + B_value * w + C_value for q, w in zip(quantity, wholesale_price)]

    # 计算R方
    r_squared = r2_score(price, predicted_price)

    # 返回R方值
    return r_squared

def getLp(quantity, wholesale_price, price, name="NAME"):
    # 创建线性规划问题
    problem = LpProblem("Constrained Linear Regression", LpMinimize)

    # 创建变量
    A = LpVariable('A')
    B = LpVariable('B')
    C = LpVariable('C')
    E = [LpVariable(f'E{i}') for i in range(len(price))]

    # 创建约束条件
    constraint1 = A <= -0.0001
    constraint2 = B >= 1.000001

    # 创建目标函数
    error = sum(E[i] for i in range(len(price)))

    # 添加约束条件和目标函数到问题中
    problem += error
    problem += constraint1
    problem += constraint2

    # 添加误差约束条件
    for q, w, p, e in zip(quantity, wholesale_price, price, E):
        problem += e >= p - (A * q + B * w + C)
        problem += e >= (A * q + B * w + C) - p

    # 求解问题
    problem.solve()

    # 打印结果
    print(name)
    print("Status:", LpStatus[problem.status])
    print("A =", value(A))
    print("B =", value(B))
    print("C =", value(C))
    
    r_squared = getRsquared(A, B, C, price, wholesale_price, quantity)
    print("R-squared:", r_squared)
    
    # Append the results to the list
    results.append({'Name': name, 'A': value(A), 'B': value(B), 'C': value(C), 'R-squared': r_squared})

# Loop through groups and get results
for name, group in groups:
    quantity = group['销量(千克)'].tolist()
    wholesale_price = group['批发价格(元/千克)'].tolist()
    price = group['销售单价(元/千克)'].tolist()
    getLp(quantity, wholesale_price, price, name)

# Convert results list to a DataFrame
results_df = pd.DataFrame(results)

# Save the DataFrame to a CSV file
results_df.to_excel('linear_regression_results.xlsx', index=False)

results_df
# Out:
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/b2f9f82d8e0f40249a2af5f56a2335b1-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/b2f9f82d8e0f40249a2af5f56a2335b1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 177 COLUMNS
# At line 945 RHS
# At line 1118 BOUNDS
# At line 1207 ENDATA
# Problem MODEL has 172 rows, 88 columns and 682 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 170 (-2) rows, 88 (0) columns and 680 (-2) elements
# Perturbing problem by 0.001% of 5.3565212 - largest nonzero change 0 ( 0%) - largest zero change 5.5691007e-05
# 0  Obj 0.00063780681 Primal inf 413.10346 (85) Dual inf 2.7381342 (85) w.o. free dual inf (0)
# 78  Obj -2.0379116e+10 Primal inf 2.9117974e+11 (45) Dual inf 0.20465926 (7) w.o. free dual inf (0)
# 78  Obj -65.939905 Primal inf 454.04035 (46) Dual inf 6.7118117e+14 (48) w.o. free dual inf (40)
# End of values pass after 79 iterations
# 79  Obj -54.739834 Primal inf 450.2748 (45) Dual inf 6.6587882e+14 (47) w.o. free dual inf (40)
# 118  Obj 423.73497 Primal inf 20.538432 (13) Dual inf 1.8675823e+14 (15)
# 158  Obj 397.56448 Dual inf 15.023615 (1)
# 164  Obj 391.2058
# Optimal - objective value 391.2058
# After Postsolve, objective 391.2058, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 391.2058014 - 164 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# 七彩椒(2)
# Status: Optimal
# A = -0.92321984
# B = 1.000001
# C = 16.493273
# R-squared: -0.2551713652435641
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/c3dd3ae952c94d3faad8dd015cd74be4-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/c3dd3ae952c94d3faad8dd015cd74be4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 185 COLUMNS
# At line 989 RHS
# At line 1170 BOUNDS
# At line 1263 ENDATA
# Problem MODEL has 180 rows, 92 columns and 714 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 178 (-2) rows, 92 (0) columns and 712 (-2) elements
# Perturbing problem by 0.001% of 12.857 - largest nonzero change 0 ( 0%) - largest zero change 5.9655728e-05
# 0  Obj 5.9655788e-05 Primal inf 41.069869 (89) Dual inf 5.620151 (89) w.o. free dual inf (0)
# 78  Obj -8.4798965 Primal inf 5.6783238e+11 (50) Dual inf 0.517209 (11) w.o. free dual inf (0)
# 78  Obj -8.4799576 Primal inf 5.6783238e+11 (50) Dual inf 1.2170303e+15 (52) w.o. free dual inf (40)
# End of values pass after 79 iterations
# 79  Obj 3.48e+10 Primal inf 5.5936522e+11 (49) Dual inf 1.207617e+15 (51) w.o. free dual inf (40)
# 134  Obj 41.444637 Primal inf 4.5728643e-07 (1) Dual inf 2e+13 (3)
# 151  Obj 41.037044
# Optimal - objective value 41.037044
# After Postsolve, objective 41.037044, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 41.03704382 - 151 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 上海青
# Status: Optimal
# A = -0.023292765
# B = 3.4276413
# C = -6.6879884
# R-squared: 0.6370099887392666
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/f74d585c696946a19798879207af23b1-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/f74d585c696946a19798879207af23b1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 189 COLUMNS
# At line 1011 RHS
# At line 1196 BOUNDS
# At line 1291 ENDATA
# Problem MODEL has 184 rows, 94 columns and 730 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 182 (-2) rows, 94 (0) columns and 728 (-2) elements
# Perturbing problem by 0.001% of 6.4031242 - largest nonzero change 0 ( 0%) - largest zero change 5.6244237e-05
# 0  Obj 6.5805823e-05 Primal inf 36.570702 (91) Dual inf 4.1011931 (91) w.o. free dual inf (0)
# 78  Obj -6.4951641e+09 Primal inf 4.4306949e+11 (52) Dual inf 0.57856307 (13) w.o. free dual inf (0)
# 78  Obj -1.1552008 Primal inf 37.37449 (52) Dual inf 8.4747575e+14 (54) w.o. free dual inf (40)
# End of values pass after 79 iterations
# 79  Obj 0.81659671 Primal inf 36.909734 (51) Dual inf 8.422318e+14 (53) w.o. free dual inf (40)
# 122  Obj 24.404294 Primal inf 0.74868108 (16) Dual inf 1.8120006e+14 (18)
# 163  Obj 25.298898
# Optimal - objective value 25.298898
# After Postsolve, objective 25.298898, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 25.29889759 - 163 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 云南油麦菜(份)
# Status: Optimal
# A = -0.0011111122
# B = 1.000001
# C = 1.9711086
# R-squared: -0.09827904613589822
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/5202c182e2cc47c0bc01489aa3810357-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/5202c182e2cc47c0bc01489aa3810357-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 187 COLUMNS
# At line 1000 RHS
# At line 1183 BOUNDS
# At line 1277 ENDATA
# Problem MODEL has 182 rows, 93 columns and 722 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 180 (-2) rows, 93 (0) columns and 720 (-2) elements
# Perturbing problem by 0.001% of 8.4099486 - largest nonzero change 0 ( 0%) - largest zero change 5.7305036e-05
# 0  Obj 9.6844713e-05 Primal inf 22.128363 (90) Dual inf 4.9954294 (90) w.o. free dual inf (0)
# 78  Obj -5.32492e+09 Primal inf 2.8926599e+11 (51) Dual inf 0.68205398 (12) w.o. free dual inf (0)
# 78  Obj -0.2883009 Primal inf 22.591724 (51) Dual inf 6.900422e+14 (53) w.o. free dual inf (40)
# End of values pass after 79 iterations
# 79  Obj 0.89569638 Primal inf 22.389235 (50) Dual inf 6.8715331e+14 (52) w.o. free dual inf (40)
# 125  Obj 26.890642 Primal inf 0.92133098 (7) Dual inf 1.412161e+14 (10)
# 159  Obj 18.732311 Dual inf 46.578729 (2)
# 164  Obj 18.273405
# Optimal - objective value 18.273405
# After Postsolve, objective 18.273405, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 18.27340476 - 164 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 云南生菜(份)
# Status: Optimal
# A = -0.0001
# B = 1.000001
# C = 1.2049973
# R-squared: 0.26353205869224794
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/10c8bab8106a4ba58cc91c4ef91788fa-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/10c8bab8106a4ba58cc91c4ef91788fa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 187 COLUMNS
# At line 1000 RHS
# At line 1183 BOUNDS
# At line 1277 ENDATA
# Problem MODEL has 182 rows, 93 columns and 722 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 180 (-2) rows, 93 (0) columns and 720 (-2) elements
# Perturbing problem by 0.001% of 15.544 - largest nonzero change 0 ( 0%) - largest zero change 6.1076065e-05
# 0  Obj 6.1076126e-05 Primal inf 39.327865 (90) Dual inf 6.32535 (90) w.o. free dual inf (0)
# 78  Obj -8.8582611 Primal inf 4.3087666e+11 (51) Dual inf 1.246358 (12) w.o. free dual inf (0)
# 78  Obj -8.8583221 Primal inf 4.3087666e+11 (51) Dual inf 1.2200394e+15 (53) w.o. free dual inf (40)
# End of values pass after 79 iterations
# 79  Obj 2.64e+10 Primal inf 4.2793319e+11 (50) Dual inf 1.2099099e+15 (52) w.o. free dual inf (40)
# 120  Obj 19.395195 Primal inf 0.93139445 (13) Dual inf 1.8132634e+14 (15)
# 160  Obj 20.245588 Dual inf 19.742161 (1)
# 163  Obj 20.183754
# Optimal - objective value 20.183754
# After Postsolve, objective 20.183754, infeasibilities - dual 0 (0), primal 3.300011e-06 (1)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 20.183756 Primal inf 2.0909091e-07 (1)
# 1  Obj 20.183757
# Optimal - objective value 20.183757
# Optimal objective 20.18375704 - 164 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 净藕(1)
# Status: Optimal
# A = -0.0001
# B = 1.3413635
# C = 1.2457667
# R-squared: 0.9601467912016861
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/5647ddc726af4393a17497dc5c1ab1a6-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/5647ddc726af4393a17497dc5c1ab1a6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 187 COLUMNS
# At line 1000 RHS
# At line 1183 BOUNDS
# At line 1277 ENDATA
# Problem MODEL has 182 rows, 93 columns and 722 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 180 (-2) rows, 93 (0) columns and 720 (-2) elements
# Perturbing problem by 0.001% of 4.8585907 - largest nonzero change 0 ( 0%) - largest zero change 5.5427803e-05
# 0  Obj 7.9942223e-05 Primal inf 58.919369 (90) Dual inf 3.1932072 (90) w.o. free dual inf (0)
# 78  Obj -1.6098012e+10 Primal inf 1.9061382e+11 (47) Dual inf 0.41497995 (12) w.o. free dual inf (0)
# 78  Obj -2.0706006 Primal inf 59.354182 (52) Dual inf 1.0236285e+15 (54) w.o. free dual inf (41)
# End of values pass after 79 iterations
# 79  Obj 0.34059594 Primal inf 58.660435 (51) Dual inf 1.0164945e+15 (53) w.o. free dual inf (41)
# 120  Obj 13.263335 Primal inf 3.3723216 (16) Dual inf 1.992028e+14 (18)
# 161  Obj 21.586486 Dual inf 61.012044 (2)
# 165  Obj 21.455357
# Optimal - objective value 21.455357
# After Postsolve, objective 21.455357, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 21.45535714 - 165 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 双孢菇(盒)
# Status: Optimal
# A = -0.0026785714
# B = 1.6071429
# C = 0.083928571
# R-squared: -0.08040378082162003
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/009d8b6a5d194233a52ebe2a0ce066d8-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/009d8b6a5d194233a52ebe2a0ce066d8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 119 COLUMNS
# At line 626 RHS
# At line 741 BOUNDS
# At line 801 ENDATA
# Problem MODEL has 114 rows, 59 columns and 450 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 112 (-2) rows, 59 (0) columns and 448 (-2) elements
# Perturbing problem by 0.001% of 21.901955 - largest nonzero change 0 ( 0%) - largest zero change 6.4436853e-05
# 0  Obj 1.6622652e-05 Primal inf 44.5379 (56) Dual inf 9.9012945 (56) w.o. free dual inf (0)
# 75  Obj 35.134514 Primal inf 3.3062734 (13)
# 87  Obj 44.110335
# Optimal - objective value 44.110318
# After Postsolve, objective 44.110318, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 44.11031821 - 87 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 圆茄子(2)
# Status: Optimal
# A = -0.0001
# B = 1.000001
# C = 3.5900509
# R-squared: 0.09843518389322292
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/f80b67023e874ec883bd71ecdd942d9e-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/f80b67023e874ec883bd71ecdd942d9e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 115 COLUMNS
# At line 604 RHS
# At line 715 BOUNDS
# At line 773 ENDATA
# Problem MODEL has 110 rows, 57 columns and 434 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 108 (-2) rows, 57 (0) columns and 432 (-2) elements
# Perturbing problem by 0.001% of 105.75823 - largest nonzero change 0 ( 0%) - largest zero change 0.00010876292
# 0  Obj 1.9975874e-05 Primal inf 9.4246685 (54) Dual inf 34.31088 (54) w.o. free dual inf (0)
# 74  Obj 23.961529 Primal inf 0.30373735 (9)
# 82  Obj 26.379159
# Optimal - objective value 26.379139
# After Postsolve, objective 26.379139, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 26.37913928 - 82 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 奶白菜
# Status: Optimal
# A = -0.020629128
# B = 1.000001
# C = 1.9511879
# R-squared: -1.3602259397247694
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/fc25b7471d8e483abffc7580fc92d71c-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/fc25b7471d8e483abffc7580fc92d71c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 185 COLUMNS
# At line 989 RHS
# At line 1170 BOUNDS
# At line 1263 ENDATA
# Problem MODEL has 180 rows, 92 columns and 714 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 178 (-2) rows, 92 (0) columns and 712 (-2) elements
# Perturbing problem by 0.001% of 5.1958316 - largest nonzero change 0 ( 0%) - largest zero change 5.5606067e-05
# 0  Obj 9.5876349e-05 Primal inf 64.201921 (89) Dual inf 2.8139316 (89) w.o. free dual inf (0)
# 78  Obj -1.0756034 Primal inf 68.208743 (50) Dual inf 0.3629321 (11) w.o. free dual inf (0)
# 111  Obj 24.727612 Primal inf 8.825529 (26)
# 137  Obj 34.75262
# Optimal - objective value 34.752524
# After Postsolve, objective 34.752524, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 34.75252365 - 137 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 姜蒜小米椒组合装(小份)
# Status: Optimal
# A = -0.0001
# B = 1.000001
# C = 2.1706974
# R-squared: -0.5959891052175115
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/8aaec876ac8e437abf9478783c3dd40a-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/8aaec876ac8e437abf9478783c3dd40a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 187 COLUMNS
# At line 1000 RHS
# At line 1183 BOUNDS
# At line 1277 ENDATA
# Problem MODEL has 182 rows, 93 columns and 722 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 180 (-2) rows, 93 (0) columns and 720 (-2) elements
# Perturbing problem by 0.001% of 6.3985102 - largest nonzero change 0 ( 0%) - largest zero change 5.6241798e-05
# 0  Obj 0.00013195016 Primal inf 44.869947 (90) Dual inf 3.6315697 (90) w.o. free dual inf (0)
# 78  Obj -7.4585603e+09 Primal inf 4.1263731e+11 (51) Dual inf 0.42911943 (12) w.o. free dual inf (0)
# 78  Obj 5.0503982 Primal inf 43.55604 (50) Dual inf 7.695326e+14 (52) w.o. free dual inf (39)
# End of values pass after 79 iterations
# 79  Obj 6.9222941 Primal inf 43.165724 (49) Dual inf 7.6571899e+14 (51) w.o. free dual inf (39)
# 125  Obj 24.607808 Primal inf 2.0369938 (13) Dual inf 2.9902783e+14 (16)
# 160  Obj 31.598982 Dual inf 27.765081 (2)
# 168  Obj 31.075427
# Optimal - objective value 31.075427
# After Postsolve, objective 31.075427, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 31.07542703 - 168 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 娃娃菜
# Status: Optimal
# A = -0.0001
# B = 1.3505405
# C = 0.49089459
# R-squared: 0.4701735380199048
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/e856cbc3a083432f98afb39ab84ad97f-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/e856cbc3a083432f98afb39ab84ad97f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 189 COLUMNS
# At line 1011 RHS
# At line 1196 BOUNDS
# At line 1291 ENDATA
# Problem MODEL has 184 rows, 94 columns and 730 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 182 (-2) rows, 94 (0) columns and 728 (-2) elements
# Perturbing problem by 0.001% of 135.98952 - largest nonzero change 0 ( 0%) - largest zero change 0.00012474305
# 0  Obj 2.7518998e-05 Primal inf 24.92131 (91) Dual inf 49.776608 (91) w.o. free dual inf (0)
# 78  Obj -6.0259705 Primal inf 1.3855629e+12 (52) Dual inf 7.6607302 (13) w.o. free dual inf (0)
# 78  Obj -6.0260925 Primal inf 1.3855629e+12 (52) Dual inf 4.4539032e+15 (54) w.o. free dual inf (40)
# End of values pass after 79 iterations
# 79  Obj 1.4006921e+11 Primal inf 1.3785594e+12 (51) Dual inf 4.4080501e+15 (53) w.o. free dual inf (40)
# 118  Obj 39.847849 Primal inf 3.9667144 (17) Dual inf 2.2612286e+14 (20)
# 153  Obj 72.965435
# Optimal - objective value 72.965435
# After Postsolve, objective 72.965435, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 72.96543457 - 153 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 小皱皮(份)
# Status: Optimal
# A = -0.038961039
# B = 1.7482517
# C = 0.57092907
# R-squared: 0.7594669058259538
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/5b33e4dc9fb24ae4b65736b43da43442-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/5b33e4dc9fb24ae4b65736b43da43442-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 185 COLUMNS
# At line 989 RHS
# At line 1170 BOUNDS
# At line 1263 ENDATA
# Problem MODEL has 180 rows, 92 columns and 714 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 178 (-2) rows, 92 (0) columns and 712 (-2) elements
# Perturbing problem by 0.001% of 6.3245553 - largest nonzero change 0 ( 0%) - largest zero change 5.6202706e-05
# 0  Obj 7.0204066e-05 Primal inf 55.397027 (89) Dual inf 4.0838378 (89) w.o. free dual inf (0)
# 78  Obj -1.2888499e+10 Primal inf 4.0463104e+11 (50) Dual inf 0.48855921 (11) w.o. free dual inf (0)
# 78  Obj 2.9969984 Primal inf 55.772506 (48) Dual inf 7.7407894e+14 (50) w.o. free dual inf (38)
# End of values pass after 79 iterations
# 79  Obj 4.3202952 Primal inf 55.54215 (47) Dual inf 7.6950123e+14 (49) w.o. free dual inf (38)
# 119  Obj 84.404131 Primal inf 4.2694499 (12) Dual inf 1.8268542e+14 (15)
# 155  Obj 77.758413
# Optimal - objective value 77.758413
# After Postsolve, objective 77.758413, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 77.75841338 - 155 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 小米椒(份)
# Status: Optimal
# A = -0.012202063
# B = 1.1277126
# C = 2.6540733
# R-squared: 0.274875926101923
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/258265a5bc274c71b301371620f2fa02-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/258265a5bc274c71b301371620f2fa02-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 185 COLUMNS
# At line 989 RHS
# At line 1170 BOUNDS
# At line 1263 ENDATA
# Problem MODEL has 180 rows, 92 columns and 714 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 178 (-2) rows, 92 (0) columns and 712 (-2) elements
# Perturbing problem by 0.001% of 4.4375194 - largest nonzero change 0 ( 0%) - largest zero change 5.5205227e-05
# 0  Obj 8.9850916e-05 Primal inf 55.538123 (89) Dual inf 2.6354238 (89) w.o. free dual inf (0)
# 78  Obj 4.0202637 Primal inf 4.615623e+11 (50) Dual inf 0.28688179 (11) w.o. free dual inf (0)
# 78  Obj 4.020174 Primal inf 4.615623e+11 (50) Dual inf 9.8327922e+14 (52) w.o. free dual inf (40)
# End of values pass after 79 iterations
# 79  Obj 1.4745835e+10 Primal inf 4.573897e+11 (49) Dual inf 9.7389555e+14 (51) w.o. free dual inf (40)
# 115  Obj 25.909485 Primal inf 3.0203023 (16) Dual inf 1.8852514e+14 (19)
# 150  Obj 31.804967
# Optimal - objective value 31.804967
# After Postsolve, objective 31.804967, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 31.80496744 - 150 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 小青菜(1)
# Status: Optimal
# A = -0.048239267
# B = 1.7326339
# C = 0.24329474
# R-squared: 0.6672346827917595
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/8c15dab2738a46a79046b8a6a90e44f3-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/8c15dab2738a46a79046b8a6a90e44f3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 141 COLUMNS
# At line 747 RHS
# At line 884 BOUNDS
# At line 955 ENDATA
# Problem MODEL has 136 rows, 70 columns and 538 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 134 (-2) rows, 70 (0) columns and 536 (-2) elements
# Perturbing problem by 0.001% of 5.427571 - largest nonzero change 0 ( 0%) - largest zero change 5.5728564e-05
# 0  Obj 0.0003472952 Primal inf 70.697121 (67) Dual inf 2.289056 (67) w.o. free dual inf (0)
# 77  Obj 24.490949 Primal inf 36.862468 (30)
# 106  Obj 62.838734
# Optimal - objective value 62.838337
# After Postsolve, objective 62.838337, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 62.83833726 - 106 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 木耳菜
# Status: Optimal
# A = -0.0025422587
# B = 1.143508
# C = 2.2906386
# R-squared: 0.6813837861107841
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/1a473204b4eb47189e10b0909cfb1883-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/1a473204b4eb47189e10b0909cfb1883-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 169 COLUMNS
# At line 901 RHS
# At line 1066 BOUNDS
# At line 1151 ENDATA
# Problem MODEL has 164 rows, 84 columns and 650 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 162 (-2) rows, 84 (0) columns and 648 (-2) elements
# Perturbing problem by 0.001% of 32.400163 - largest nonzero change 0 ( 0%) - largest zero change 6.9986161e-05
# 0  Obj 0.00015437998 Primal inf 65.104923 (81) Dual inf 14.515184 (81) w.o. free dual inf (0)
# 78  Obj -6.4572755 Primal inf 67.941528 (43) Dual inf 0.6356647 (3) w.o. free dual inf (0)
# 109  Obj 67.590865 Primal inf 16.483164 (29)
# 127  Obj 76.603251
# Optimal - objective value 76.60307
# After Postsolve, objective 76.60307, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 76.6030704 - 127 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 枝江青梗散花
# Status: Optimal
# A = -0.014805664
# B = 1.1673858
# C = 2.4356871
# R-squared: 0.7300859019842181
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/6e0b290f1c2d477c86cda75ad98d72d2-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/6e0b290f1c2d477c86cda75ad98d72d2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 117 COLUMNS
# At line 615 RHS
# At line 728 BOUNDS
# At line 787 ENDATA
# Problem MODEL has 112 rows, 58 columns and 442 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 110 (-2) rows, 58 (0) columns and 440 (-2) elements
# Perturbing problem by 0.001% of 7.6229921 - largest nonzero change 0 ( 0%) - largest zero change 5.6889054e-05
# 0  Obj 0.00071769876 Primal inf 99.990955 (55) Dual inf 2.5258023 (55) w.o. free dual inf (0)
# 73  Obj 74.619177 Primal inf 48.003272 (24)
# 83  Obj 88.835935
# Optimal - objective value 88.835218
# After Postsolve, objective 88.835218, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 88.83521757 - 83 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 洪湖藕带
# Status: Optimal
# A = -0.50022149
# B = 1.000001
# C = 9.8821049
# R-squared: 0.8281465442922801
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/a9a612f7c7c24ab69aa5669cbba9ab32-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/a9a612f7c7c24ab69aa5669cbba9ab32-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 147 COLUMNS
# At line 780 RHS
# At line 923 BOUNDS
# At line 997 ENDATA
# Problem MODEL has 142 rows, 73 columns and 562 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 140 (-2) rows, 73 (0) columns and 560 (-2) elements
# Perturbing problem by 0.001% of 5 - largest nonzero change 0 ( 0%) - largest zero change 5.5502552e-05
# 0  Obj 5.8961779e-05 Primal inf 17.910747 (70) Dual inf 2.5379936 (70) w.o. free dual inf (0)
# 77  Obj 6.3752596 Primal inf 3.7911151 (32)
# 104  Obj 10.358464
# Optimal - objective value 10.358405
# After Postsolve, objective 10.358405, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 10.35840465 - 104 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 海鲜菇(包)
# Status: Optimal
# A = -0.0001
# B = 1.000001
# C = 0.9007979
# R-squared: -0.031703438074570434
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/115a085cabb34372985a20186f314cd0-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/115a085cabb34372985a20186f314cd0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 125 COLUMNS
# At line 659 RHS
# At line 780 BOUNDS
# At line 843 ENDATA
# Problem MODEL has 120 rows, 62 columns and 474 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 118 (-2) rows, 62 (0) columns and 472 (-2) elements
# Perturbing problem by 0.001% of 6 - largest nonzero change 0 ( 0%) - largest zero change 5.6031147e-05
# 0  Obj 5.6031203e-05 Primal inf 40.111078 (59) Dual inf 2.491241 (59) w.o. free dual inf (0)
# 77  Obj 40.143491 Primal inf 1.2252946 (8)
# 88  Obj 43.300287
# Optimal - objective value 43.3001
# After Postsolve, objective 43.3001, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 43.3001 - 88 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 白玉菇(袋)
# Status: Optimal
# A = -0.0001
# B = 3.3333333
# C = -6.8665667
# R-squared: 0.1615671617921699
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/20ec6d41b1f7419e9c05dfde9958a989-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/20ec6d41b1f7419e9c05dfde9958a989-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 181 COLUMNS
# At line 967 RHS
# At line 1144 BOUNDS
# At line 1235 ENDATA
# Problem MODEL has 176 rows, 90 columns and 698 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 174 (-2) rows, 90 (0) columns and 696 (-2) elements
# Perturbing problem by 0.001% of 29.206 - largest nonzero change 0 ( 0%) - largest zero change 6.829774e-05
# 0  Obj 6.8297808e-05 Primal inf 16.708814 (87) Dual inf 10.807843 (87) w.o. free dual inf (0)
# 78  Obj 2.9915779 Primal inf 16.915531 (48) Dual inf 1.066551 (9) w.o. free dual inf (0)
# 112  Obj 45.798359 Primal inf 2.9628217 (26)
# 135  Obj 54.990265
# Optimal - objective value 54.990178
# After Postsolve, objective 54.990178, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 54.99017756 - 135 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 竹叶菜
# Status: Optimal
# A = -0.0001
# B = 1.28416
# C = 0.62725594
# R-squared: 0.8671488760638484
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/b88d288dbf5e492581f1094f2ea7e80c-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/b88d288dbf5e492581f1094f2ea7e80c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 189 COLUMNS
# At line 1011 RHS
# At line 1196 BOUNDS
# At line 1291 ENDATA
# Problem MODEL has 184 rows, 94 columns and 730 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 182 (-2) rows, 94 (0) columns and 728 (-2) elements
# Perturbing problem by 0.001% of 6.3218668 - largest nonzero change 0 ( 0%) - largest zero change 5.6201285e-05
# 0  Obj 0.00010815321 Primal inf 60.087842 (91) Dual inf 3.7495518 (91) w.o. free dual inf (0)
# 78  Obj -3.1749535 Primal inf 4.6557518e+11 (52) Dual inf 0.43870349 (13) w.o. free dual inf (0)
# 78  Obj -3.175087 Primal inf 4.6557518e+11 (52) Dual inf 9.8800351e+14 (54) w.o. free dual inf (40)
# End of values pass after 79 iterations
# 79  Obj 2.0236106e+10 Primal inf 4.6041545e+11 (51) Dual inf 9.8336395e+14 (53) w.o. free dual inf (40)
# 125  Obj 37.922002 Primal inf 3.1844789 (13) Dual inf 1.8542081e+14 (16)
# 170  Obj 48.737991 Dual inf 100.21237 (2)
# 184  Obj 46.487996
# Optimal - objective value 46.487996
# After Postsolve, objective 46.487996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 46.4879956 - 184 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 紫茄子(2)
# Status: Optimal
# A = -0.0054221898
# B = 1.000001
# C = 2.6228175
# R-squared: 0.4864764698498658
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/f65a25e031e44957a6d9a05c5beb5d95-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/f65a25e031e44957a6d9a05c5beb5d95-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 189 COLUMNS
# At line 1011 RHS
# At line 1196 BOUNDS
# At line 1291 ENDATA
# Problem MODEL has 184 rows, 94 columns and 730 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 182 (-2) rows, 94 (0) columns and 728 (-2) elements
# Perturbing problem by 0.001% of 5.4550175 - largest nonzero change 0 ( 0%) - largest zero change 5.5743072e-05
# 0  Obj 0.00040771365 Primal inf 156.72999 (91) Dual inf 3.1776921 (91) w.o. free dual inf (0)
# 78  Obj 17.7815 Primal inf 4.0686547e+11 (52) Dual inf 0.42200411 (13) w.o. free dual inf (0)
# 78  Obj 17.781092 Primal inf 4.0686547e+11 (52) Dual inf 9.4292035e+14 (54) w.o. free dual inf (40)
# End of values pass after 79 iterations
# 79  Obj 1.5148717e+10 Primal inf 4.0328842e+11 (51) Dual inf 9.3537752e+14 (53) w.o. free dual inf (40)
# 124  Obj 166.3641 Primal inf 15.367646 (20) Dual inf 2.703451e+14 (23)
# 166  Obj 180.42583 Dual inf 4.6859948 (2)
# 169  Obj 180.33545
# Optimal - objective value 180.33545
# After Postsolve, objective 180.33545, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 180.3354486 - 169 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 红椒(2)
# Status: Optimal
# A = -0.42570324
# B = 1.000001
# C = 6.5764534
# R-squared: -0.002122890224048657
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/aa261530ef0c43b1ab1081b22b4002f0-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/aa261530ef0c43b1ab1081b22b4002f0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 121 COLUMNS
# At line 637 RHS
# At line 754 BOUNDS
# At line 815 ENDATA
# Problem MODEL has 116 rows, 60 columns and 458 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 114 (-2) rows, 60 (0) columns and 456 (-2) elements
# Perturbing problem by 0.001% of 3.9343748 - largest nonzero change 0 ( 0%) - largest zero change 5.4939267e-05
# 0  Obj 0.00050804037 Primal inf 133.47497 (57) Dual inf 1.126972 (57) w.o. free dual inf (0)
# 75  Obj 20.882396 Primal inf 26.826593 (22)
# 92  Obj 32.594087
# Optimal - objective value 32.59356
# After Postsolve, objective 32.59356, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 32.59356031 - 92 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 红莲藕带
# Status: Optimal
# A = -0.23348452
# B = 1.0372837
# C = 3.7094774
# R-squared: 0.5962437875689552
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/78a62cceaa564b659ecf2cd6b22b5b2f-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/78a62cceaa564b659ecf2cd6b22b5b2f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 135 COLUMNS
# At line 714 RHS
# At line 845 BOUNDS
# At line 913 ENDATA
# Problem MODEL has 130 rows, 67 columns and 514 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 128 (-2) rows, 67 (0) columns and 512 (-2) elements
# Perturbing problem by 0.001% of 65.021533 - largest nonzero change 0 ( 0%) - largest zero change 8.7229678e-05
# 0  Obj 2.0125963e-05 Primal inf 31.91869 (64) Dual inf 22.6437 (64) w.o. free dual inf (0)
# 77  Obj 46.14785 Primal inf 10.051035 (25)
# 102  Obj 58.320686
# Optimal - objective value 58.320661
# After Postsolve, objective 58.320661, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 58.32066149 - 102 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 红薯尖
# Status: Optimal
# A = -0.0001
# B = 1.2396247
# C = 1.8024995
# R-squared: 0.7586661364758078
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/9d53744b780c491bbd0316158ba5bb19-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/9d53744b780c491bbd0316158ba5bb19-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 189 COLUMNS
# At line 1011 RHS
# At line 1196 BOUNDS
# At line 1291 ENDATA
# Problem MODEL has 184 rows, 94 columns and 730 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 182 (-2) rows, 94 (0) columns and 728 (-2) elements
# Perturbing problem by 0.001% of 7.6933054 - largest nonzero change 0 ( 0%) - largest zero change 5.6926221e-05
# 0  Obj 0.00012233525 Primal inf 42.36506 (91) Dual inf 4.4405631 (91) w.o. free dual inf (0)
# 78  Obj 3.7460519 Primal inf 42.145844 (52) Dual inf 0.5456392 (13) w.o. free dual inf (0)
# 114  Obj 38.722013 Primal inf 3.7426484 (26)
# 142  Obj 48.512451
# Optimal - objective value 48.512293
# After Postsolve, objective 48.512293, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 48.51229271 - 142 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 芜湖青椒(1)
# Status: Optimal
# A = -0.0047771775
# B = 1.297625
# C = 0.91300985
# R-squared: 0.6155124810661099
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/44b42dbdaabc4765b1b05b530b1f45a9-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/44b42dbdaabc4765b1b05b530b1f45a9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 181 COLUMNS
# At line 967 RHS
# At line 1144 BOUNDS
# At line 1235 ENDATA
# Problem MODEL has 176 rows, 90 columns and 698 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 174 (-2) rows, 90 (0) columns and 696 (-2) elements
# Perturbing problem by 0.001% of 14.705 - largest nonzero change 0 ( 0%) - largest zero change 6.0632573e-05
# 0  Obj 6.0632634e-05 Primal inf 19.668539 (87) Dual inf 7.104933 (87) w.o. free dual inf (0)
# 78  Obj -7.5993937e+09 Primal inf 1.6443103e+11 (48) Dual inf 0.717001 (9) w.o. free dual inf (0)
# 78  Obj -1.9560833 Primal inf 2.3246953e+11 (48) Dual inf 8.021677e+14 (50) w.o. free dual inf (40)
# End of values pass after 79 iterations
# 79  Obj 1.67e+10 Primal inf 2.3010744e+11 (47) Dual inf 7.9897477e+14 (49) w.o. free dual inf (40)
# ...
# At line 189 COLUMNS
# At line 1011 RHS
# At line 1196 BOUNDS
# At line 1291 ENDATA
# Problem MODEL has 184 rows, 94 columns and 730 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 182 (-2) rows, 94 (0) columns and 728 (-2) elements
# Perturbing problem by 0.001% of 27.527 - largest nonzero change 0 ( 0%) - largest zero change 6.7410228e-05
# 0  Obj 6.7410295e-05 Primal inf 25.892704 (91) Dual inf 13.481909 (91) w.o. free dual inf (0)
# 78  Obj -2.0999326e+10 Primal inf 5.8920245e+11 (52) Dual inf 1.727877 (13) w.o. free dual inf (0)
# 78  Obj -2.8990282 Primal inf 26.147416 (52) Dual inf 9.8482305e+14 (54) w.o. free dual inf (40)
# End of values pass after 79 iterations
# 79  Obj 0.3026496 Primal inf 25.957474 (51) Dual inf 9.8004766e+14 (53) w.o. free dual inf (40)
# 123  Obj 45.727058 Primal inf 0.92744452 (14) Dual inf 1.899229e+14 (17)
# 159  Obj 56.239637
# Optimal - objective value 56.239637
# After Postsolve, objective 56.239637, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 56.23963744 - 159 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 西兰花
# Status: Optimal
# A = -0.02869312
# B = 1.2540355
# C = 2.052532
# R-squared: 0.6949483395356312
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/890c60af4b5a4cb081390c33c6fceeac-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/890c60af4b5a4cb081390c33c6fceeac-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 187 COLUMNS
# At line 1000 RHS
# At line 1183 BOUNDS
# At line 1277 ENDATA
# Problem MODEL has 182 rows, 93 columns and 722 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 180 (-2) rows, 93 (0) columns and 720 (-2) elements
# Perturbing problem by 0.001% of 6.3099795 - largest nonzero change 0 ( 0%) - largest zero change 5.6195001e-05
# 0  Obj 0.00035985659 Primal inf 179.70341 (90) Dual inf 3.6581126 (90) w.o. free dual inf (0)
# 78  Obj -3.7976952 Primal inf 5.4756079e+11 (51) Dual inf 0.48938942 (12) w.o. free dual inf (0)
# 78  Obj -3.7980537 Primal inf 5.4756079e+11 (51) Dual inf 9.741298e+14 (53) w.o. free dual inf (40)
# End of values pass after 79 iterations
# 79  Obj 2.3736257e+10 Primal inf 5.4229736e+11 (50) Dual inf 9.667459e+14 (52) w.o. free dual inf (40)
# 122  Obj 93.506405 Primal inf 3.6382711 (17) Dual inf 1.8024398e+14 (18)
# 163  Obj 92.221628 Dual inf 58.717092 (2)
# 183  Obj 79.001477
# Optimal - objective value 79.001477
# After Postsolve, objective 79.001477, infeasibilities - dual 0 (0), primal 6.3535065e-07 (2)
# Presolved model was optimal, full model needs cleaning up
# Optimal - objective value 79.001478
# Optimal objective 79.0014778 - 183 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 西峡花菇(1)
# Status: Optimal
# A = -0.071047957
# B = 1.5182948
# C = 0.57804618
# R-squared: 0.04407954603150266
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/ed860456ab6e4b75b80b7fa78cf48fe7-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/ed860456ab6e4b75b80b7fa78cf48fe7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 187 COLUMNS
# At line 1000 RHS
# At line 1183 BOUNDS
# At line 1277 ENDATA
# Problem MODEL has 182 rows, 93 columns and 722 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 180 (-2) rows, 93 (0) columns and 720 (-2) elements
# Perturbing problem by 0.001% of 7.7459667 - largest nonzero change 0 ( 0%) - largest zero change 5.6954058e-05
# 0  Obj 2.8477057e-05 Primal inf 20.758977 (90) Dual inf 4.7443992 (90) w.o. free dual inf (0)
# 78  Obj -8.1994305e+09 Primal inf 6.2361517e+11 (51) Dual inf 0.51847692 (12) w.o. free dual inf (0)
# 78  Obj 0.89459959 Primal inf 20.985946 (52) Dual inf 1.0193822e+15 (54) w.o. free dual inf (41)
# End of values pass after 79 iterations
# 79  Obj 1.7284974 Primal inf 20.852417 (51) Dual inf 1.0122846e+15 (53) w.o. free dual inf (41)
# 122  Obj 76.135001 Primal inf 1.6237547 (11) Dual inf 1.5962655e+14 (13)
# 159  Obj 45.049088 Dual inf 38.581235 (3)
# 167  Obj 41.739941
# Optimal - objective value 41.739941
# After Postsolve, objective 41.739941, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 41.73994073 - 167 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 金针菇(盒)
# Status: Optimal
# A = -0.0001
# B = 2.0444898
# C = -0.9619102
# R-squared: 0.005711383986779728
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/85c837fdf0ff495790403cf911036fdf-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/85c837fdf0ff495790403cf911036fdf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 75 COLUMNS
# At line 384 RHS
# At line 455 BOUNDS
# At line 493 ENDATA
# Problem MODEL has 70 rows, 37 columns and 274 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 68 (-2) rows, 37 (0) columns and 272 (-2) elements
# Perturbing problem by 0.001% of 12.638 - largest nonzero change 0 ( 0%) - largest zero change 5.9539966e-05
# 0  Obj 5.9540025e-05 Primal inf 21.276733 (34) Dual inf 2.749626 (34) w.o. free dual inf (0)
# 48  Obj 18.260434 Primal inf 3.6823483 (12)
# 53  Obj 20.432162
# Optimal - objective value 20.432093
# After Postsolve, objective 20.432093, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 20.43209264 - 53 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 长线茄
# Status: Optimal
# A = -0.0001
# B = 1.1700556
# C = 3.8799415
# R-squared: 0.4939668041610411
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/23e37900d68946318c192ca5803497c0-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/23e37900d68946318c192ca5803497c0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 121 COLUMNS
# At line 637 RHS
# At line 754 BOUNDS
# At line 815 ENDATA
# Problem MODEL has 116 rows, 60 columns and 458 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 114 (-2) rows, 60 (0) columns and 456 (-2) elements
# Perturbing problem by 0.001% of 12 - largest nonzero change 0 ( 0%) - largest zero change 5.9202722e-05
# 0  Obj 5.9202781e-05 Primal inf 27.57863 (57) Dual inf 3.011143 (57) w.o. free dual inf (0)
# 76  Obj 41.858975 Primal inf 1.9865549 (8)
# 89  Obj 48.915548
# Optimal - objective value 48.915489
# After Postsolve, objective 48.915489, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 48.91548916 - 89 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 青红杭椒组合装(份)
# Status: Optimal
# A = -0.086363723
# B = 1.000001
# C = 2.3563602
# R-squared: -2.1177459198997277
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/6c87255a1e6a42849d1470ba952e6744-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/6c87255a1e6a42849d1470ba952e6744-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 91 COLUMNS
# At line 472 RHS
# At line 559 BOUNDS
# At line 605 ENDATA
# Problem MODEL has 86 rows, 45 columns and 338 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 84 (-2) rows, 45 (0) columns and 336 (-2) elements
# Perturbing problem by 0.001% of 13 - largest nonzero change 0 ( 0%) - largest zero change 5.9731318e-05
# 0  Obj 5.9731377e-05 Primal inf 11.839834 (42) Dual inf 2.711958 (42) w.o. free dual inf (0)
# 60  Obj 26.234515 Primal inf 0.25565583 (3)
# 66  Obj 27.633706
# Optimal - objective value 27.633646
# After Postsolve, objective 27.633646, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 27.63364636 - 66 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 青线椒(份)
# Status: Optimal
# A = -0.047272702
# B = 1.000001
# C = 1.7145424
# R-squared: 0.3615670544137317
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/b5894219f5d24ef29cc8ea48528e81f2-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/b5894219f5d24ef29cc8ea48528e81f2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 593 RHS
# At line 702 BOUNDS
# At line 759 ENDATA
# Problem MODEL has 108 rows, 56 columns and 426 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 106 (-2) rows, 56 (0) columns and 424 (-2) elements
# Perturbing problem by 0.001% of 4.3670072 - largest nonzero change 0 ( 0%) - largest zero change 5.5167954e-05
# 0  Obj 0.00028092469 Primal inf 73.009114 (53) Dual inf 1.2825359 (53) w.o. free dual inf (0)
# 71  Obj 45.772312 Primal inf 3.8474923 (10)
# 84  Obj 49.658543
# Optimal - objective value 49.658143
# After Postsolve, objective 49.658143, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 49.65814257 - 84 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 青茄子(1)
# Status: Optimal
# A = -0.0001
# B = 1.4256333
# C = 0.42429907
# R-squared: 0.7706755793998902
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/65e2368774d04f158e3485e88a26b303-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/l_/t15z68h5545gnmg_nk6tn8r00000gn/T/65e2368774d04f158e3485e88a26b303-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 177 COLUMNS
# At line 945 RHS
# At line 1118 BOUNDS
# At line 1207 ENDATA
# Problem MODEL has 172 rows, 88 columns and 682 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 170 (-2) rows, 88 (0) columns and 680 (-2) elements
# Perturbing problem by 0.001% of 5.6890527 - largest nonzero change 0 ( 0%) - largest zero change 5.5866782e-05
# 0  Obj 0.00061783421 Primal inf 188.72809 (85) Dual inf 2.8040317 (85) w.o. free dual inf (0)
# 78  Obj -18.059273 Primal inf 196.40379 (46) Dual inf 0.25771233 (7) w.o. free dual inf (0)
# 109  Obj 106.9457 Primal inf 20.744362 (25)
# 136  Obj 124.26419
# Optimal - objective value 124.2632
# After Postsolve, objective 124.2632, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 124.2631953 - 136 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 高瓜(1)
# Status: Optimal
# A = -0.10150223
# B = 1.6118555
# C = -0.74648802
# R-squared: 0.6449132390653693
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
#             Name         A         B          C  R-squared
# 0         七彩椒(2) -0.923220  1.000001  16.493273  -0.255171
# 1            上海青 -0.023293  3.427641  -6.687988   0.637010
# 2       云南油麦菜(份) -0.001111  1.000001   1.971109  -0.098279
# 3        云南生菜(份) -0.000100  1.000001   1.204997   0.263532
# 4          净藕(1) -0.000100  1.341363   1.245767   0.960147
# 5         双孢菇(盒) -0.002679  1.607143   0.083929  -0.080404
# 6         圆茄子(2) -0.000100  1.000001   3.590051   0.098435
# 7            奶白菜 -0.020629  1.000001   1.951188  -1.360226
# 8   姜蒜小米椒组合装(小份) -0.000100  1.000001   2.170697  -0.595989
# 9            娃娃菜 -0.000100  1.350540   0.490895   0.470174
# 10        小皱皮(份) -0.038961  1.748252   0.570929   0.759467
# 11        小米椒(份) -0.012202  1.127713   2.654073   0.274876
# 12        小青菜(1) -0.048239  1.732634   0.243295   0.667235
# 13           木耳菜 -0.002542  1.143508   2.290639   0.681384
# 14        枝江青梗散花 -0.014806  1.167386   2.435687   0.730086
# 15          洪湖藕带 -0.500221  1.000001   9.882105   0.828147
# 16        海鲜菇(包) -0.000100  1.000001   0.900798  -0.031703
# 17        白玉菇(袋) -0.000100  3.333333  -6.866567   0.161567
# 18           竹叶菜 -0.000100  1.284160   0.627256   0.867149
# 19        紫茄子(2) -0.005422  1.000001   2.622818   0.486476
# 20         红椒(2) -0.425703  1.000001   6.576453  -0.002123
# 21          红莲藕带 -0.233485  1.037284   3.709477   0.596244
# 22           红薯尖 -0.000100  1.239625   1.802499   0.758666
# 23       芜湖青椒(1) -0.004777  1.297625   0.913010   0.615512
# 24            苋菜 -0.000100  1.237585   0.691662   0.621020
# 25            菜心 -0.373519  1.049407   4.302037   0.062728
# 26         菠菜(份) -0.011071  1.000001   1.743926   0.338417
# 27            菱角 -0.000100  1.000001   4.760086   0.826860
# 28        虫草花(份) -0.008140  2.441861  -2.613954   0.315515
# 29           螺丝椒 -0.061124  1.000001   3.718573   0.624408
# 30        螺丝椒(份) -0.000100  1.000001   3.683096  -0.183329
# 31  蟹味菇与白玉菇双拼(盒) -0.000100  1.470686   1.429314  -0.302904
# 32           西兰花 -0.028693  1.254036   2.052532   0.694948
# 33       西峡花菇(1) -0.071048  1.518295   0.578046   0.044080
# 34        金针菇(盒) -0.000100  2.044490  -0.961910   0.005711
# 35           长线茄 -0.000100  1.170056   3.879942   0.493967
# 36    青红杭椒组合装(份) -0.086364  1.000001   2.356360  -2.117746
# 37        青线椒(份) -0.047273  1.000001   1.714542   0.361567
# 38        青茄子(1) -0.000100  1.425633   0.424299   0.770676
# 39         高瓜(1) -0.101502  1.611856  -0.746488   0.644913

# %% [markdown]
# # 合并批发价和多元线性回归结果

# %%
p=pd.read_excel('预测批发价.xlsx')
df = pd.read_excel('linear_regression_results.xlsx')
df['p']=p['批发价格(元/千克)']
df
# Out:
#             Name         A         B          C  R-squared      p
# 0         七彩椒(2) -0.923220  1.000001  16.493273  -0.255171  12.13
# 1            上海青 -0.023293  3.427641  -6.687988   0.637010   4.09
# 2       云南油麦菜(份) -0.001111  1.000001   1.971109  -0.098279   2.66
# 3        云南生菜(份) -0.000100  1.000001   1.204997   0.263532   2.84
# 4          净藕(1) -0.000100  1.341363   1.245767   0.960147   5.68
# 5         双孢菇(盒) -0.002679  1.607143   0.083929  -0.080404   3.49
# 6         圆茄子(2) -0.000100  1.000001   3.590051   0.098435  10.38
# 7            奶白菜 -0.020629  1.000001   1.951188  -1.360226   3.41
# 8   姜蒜小米椒组合装(小份) -0.000100  1.000001   2.170697  -0.595989   3.20
# 9            娃娃菜 -0.000100  1.350540   0.490895   0.470174   9.19
# 10        小皱皮(份) -0.038961  1.748252   0.570929   0.759467   2.56
# 11        小米椒(份) -0.012202  1.127713   2.654073   0.274876   2.33
# 12        小青菜(1) -0.048239  1.732634   0.243295   0.667235   4.40
# 13           木耳菜 -0.002542  1.143508   2.290639   0.681384   2.10
# 14        枝江青梗散花 -0.014806  1.167386   2.435687   0.730086   2.11
# 15          洪湖藕带 -0.500221  1.000001   9.882105   0.828147   2.70
# 16        海鲜菇(包) -0.000100  1.000001   0.900798  -0.031703   3.12
# 17        白玉菇(袋) -0.000100  3.333333  -6.866567   0.161567   1.53
# 18           竹叶菜 -0.000100  1.284160   0.627256   0.867149   8.39
# 19        紫茄子(2) -0.005422  1.000001   2.622818   0.486476  18.00
# 20         红椒(2) -0.425703  1.000001   6.576453  -0.002123   1.95
# 21          红莲藕带 -0.233485  1.037284   3.709477   0.596244   3.29
# 22           红薯尖 -0.000100  1.239625   1.802499   0.758666   2.15
# 23       芜湖青椒(1) -0.004777  1.297625   0.913010   0.615512   4.34
# 24            苋菜 -0.000100  1.237585   0.691662   0.621020   3.43
# 25            菜心 -0.373519  1.049407   4.302037   0.062728  12.72
# 26         菠菜(份) -0.011071  1.000001   1.743926   0.338417   5.29
# 27            菱角 -0.000100  1.000001   4.760086   0.826860   2.60
# 28        虫草花(份) -0.008140  2.441861  -2.613954   0.315515   3.63
# 29           螺丝椒 -0.061124  1.000001   3.718573   0.624408   2.21
# 30        螺丝椒(份) -0.000100  1.000001   3.683096  -0.183329   4.62
# 31  蟹味菇与白玉菇双拼(盒) -0.000100  1.470686   1.429314  -0.302904   9.66
# 32           西兰花 -0.028693  1.254036   2.052532   0.694948   4.07
# 33       西峡花菇(1) -0.071048  1.518295   0.578046   0.044080   9.16
# 34        金针菇(盒) -0.000100  2.044490  -0.961910   0.005711   2.60
# 35           长线茄 -0.000100  1.170056   3.879942   0.493967   8.97
# 36    青红杭椒组合装(份) -0.086364  1.000001   2.356360  -2.117746   4.29
# 37        青线椒(份) -0.047273  1.000001   1.714542   0.361567   3.12
# 38        青茄子(1) -0.000100  1.425633   0.424299   0.770676   7.59
# 39         高瓜(1) -0.101502  1.611856  -0.746488   0.644913  15.60

# %% [markdown]
# $$w=ax^2+(b-1)px+cx\space\space\space\space\space\space\space\space(满足a<0且b>1)$$
# 显然当且仅当$x=\frac{1-b}{2a}p$有w最大值
# $Y=aX1+bX2+c$

# %%
df['销量']=(1-df['B'])/(2*df['A'])*df['p']
df['最大利润']=(df['A']*df['销量']*df['销量'])+(df['B']*df['p']*df['销量'])+df['C']*df['销量']
df['售价']=df['A']*df['销量']+df['B']*df['p']+df['C']
df['p'].rename('批发价')
df
# Out:
#             Name         A         B          C  R-squared      p  \
# 0         七彩椒(2) -0.923220  1.000001  16.493273  -0.255171  12.13
# 1            上海青 -0.023293  3.427641  -6.687988   0.637010   4.09
# 2       云南油麦菜(份) -0.001111  1.000001   1.971109  -0.098279   2.66
# 3        云南生菜(份) -0.000100  1.000001   1.204997   0.263532   2.84
# 4          净藕(1) -0.000100  1.341363   1.245767   0.960147   5.68
# 5         双孢菇(盒) -0.002679  1.607143   0.083929  -0.080404   3.49
# 6         圆茄子(2) -0.000100  1.000001   3.590051   0.098435  10.38
# 7            奶白菜 -0.020629  1.000001   1.951188  -1.360226   3.41
# 8   姜蒜小米椒组合装(小份) -0.000100  1.000001   2.170697  -0.595989   3.20
# 9            娃娃菜 -0.000100  1.350540   0.490895   0.470174   9.19
# 10        小皱皮(份) -0.038961  1.748252   0.570929   0.759467   2.56
# 11        小米椒(份) -0.012202  1.127713   2.654073   0.274876   2.33
# 12        小青菜(1) -0.048239  1.732634   0.243295   0.667235   4.40
# 13           木耳菜 -0.002542  1.143508   2.290639   0.681384   2.10
# 14        枝江青梗散花 -0.014806  1.167386   2.435687   0.730086   2.11
# 15          洪湖藕带 -0.500221  1.000001   9.882105   0.828147   2.70
# 16        海鲜菇(包) -0.000100  1.000001   0.900798  -0.031703   3.12
# 17        白玉菇(袋) -0.000100  3.333333  -6.866567   0.161567   1.53
# 18           竹叶菜 -0.000100  1.284160   0.627256   0.867149   8.39
# 19        紫茄子(2) -0.005422  1.000001   2.622818   0.486476  18.00
# 20         红椒(2) -0.425703  1.000001   6.576453  -0.002123   1.95
# 21          红莲藕带 -0.233485  1.037284   3.709477   0.596244   3.29
# 22           红薯尖 -0.000100  1.239625   1.802499   0.758666   2.15
# 23       芜湖青椒(1) -0.004777  1.297625   0.913010   0.615512   4.34
# 24            苋菜 -0.000100  1.237585   0.691662   0.621020   3.43
# 25            菜心 -0.373519  1.049407   4.302037   0.062728  12.72
# 26         菠菜(份) -0.011071  1.000001   1.743926   0.338417   5.29
# 27            菱角 -0.000100  1.000001   4.760086   0.826860   2.60
# 28        虫草花(份) -0.008140  2.441861  -2.613954   0.315515   3.63
# 29           螺丝椒 -0.061124  1.000001   3.718573   0.624408   2.21
# 30        螺丝椒(份) -0.000100  1.000001   3.683096  -0.183329   4.62
# 31  蟹味菇与白玉菇双拼(盒) -0.000100  1.470686   1.429314  -0.302904   9.66
# 32           西兰花 -0.028693  1.254036   2.052532   0.694948   4.07
# 33       西峡花菇(1) -0.071048  1.518295   0.578046   0.044080   9.16
# 34        金针菇(盒) -0.000100  2.044490  -0.961910   0.005711   2.60
# 35           长线茄 -0.000100  1.170056   3.879942   0.493967   8.97
# 36    青红杭椒组合装(份) -0.086364  1.000001   2.356360  -2.117746   4.29
# 37        青线椒(份) -0.047273  1.000001   1.714542   0.361567   3.12
# 38        青茄子(1) -0.000100  1.425633   0.424299   0.770676   7.59
# 39         高瓜(1) -0.101502  1.611856  -0.746488   0.644913  15.60
#
#               销量           最大利润         售价
# 0       0.000007       0.000188  28.623279
# 1     213.135987     504.394425   2.366538
# 2       0.001197       0.005543   4.631110
# 3       0.014200       0.057439   4.044999
# 4    9694.723400   76542.158670   7.895239
# 5     395.533365    1832.661500   4.633393
# 6       0.051900       0.725046  13.970056
# 7       0.000083       0.000443   5.361190
# 8       0.016000       0.085931   5.370699
# 9   16107.335975  181878.048921  11.291628
# 10     24.582562     100.510508   4.088691
# 11     12.193445      62.587225   5.132858
# 12     33.412501     208.998181   6.255089
# 13     59.271466     269.170812   4.541322
# 14     11.927329      56.324175   4.722279
# 15      0.000003       0.000034  12.582106
# 16      0.015600       0.062724   4.020799
# 17  17849.999745  -63395.465145  -3.551567
# 18  11920.512000  121700.168274  10.209307
# 19      0.001660       0.034231  20.622826
# 20      0.000002       0.000020   8.526454
# 21      0.262680       1.854733   7.060809
# 22   2575.965525   10845.062288   4.210096
# 23    135.194108     797.490588   5.898856
# 24   4074.587895   18454.301314   4.529121
# 25      0.841264      14.584377  17.336265
# 26      0.000239       0.001680   7.033928
# 27      0.013000       0.095681   7.360087
# 28    321.514293    1168.068920   3.633023
# 29      0.000018       0.000107   5.928574
# 30      0.023100       0.191802   8.303099
# 31  22734.148290  303790.251937  13.362729
# 32     18.016941     119.623374   6.639494
# 33     33.411097     404.669740  12.111836
# 34  13578.367400   40679.791264   2.995927
# 35   7626.993660  103823.525581  13.612641
# 36      0.000025       0.000165   6.646362
# 37      0.000033       0.000160   4.834544
# 38  16152.783735  155544.481904   9.629577
# 39     47.018404     922.782494  19.625985

# %%
Y=pd.read_excel('预测销量.xlsx')
df['销量']=Y['销量(千克)_预测']
df['最大利润']=df['销量']*(df['售价']-df['p'])
df.sort_values(by='最大利润', ascending=False)  
df.to_excel('Q3-answer.xlsx', index=False)

# %%
import pandas as pd
df=pd.read_excel('Q3-answer.xlsx')
df=df.head(27)
df.to_excel('Q3-answer(final).xlsx', index=False)
df
# Out:
#             Name         A         B         C  R-squared    批发价         销量  \
# 0           洪湖藕带 -0.500221  1.000001  9.882105   0.828147   2.70   8.044053
# 1         圆茄子(2) -0.000100  1.000001  3.590051   0.098435  10.38  15.487791
# 2       云南油麦菜(份) -0.001111  1.000001  1.971109  -0.098279   2.66  22.482164
# 3          红椒(2) -0.425703  1.000001  6.576453  -0.002123   1.95   6.341162
# 4          净藕(1) -0.000100  1.341363  1.245767   0.960147   5.68  16.798942
# 5         小米椒(份) -0.012202  1.127713  2.654073   0.274876   2.33  11.772556
# 6   姜蒜小米椒组合装(小份) -0.000100  1.000001  2.170697  -0.595989   3.20  13.781611
# 7            奶白菜 -0.020629  1.000001  1.951188  -1.360226   3.41  14.176884
# 8            木耳菜 -0.002542  1.143508  2.290639   0.681384   2.10  11.104873
# 9            娃娃菜 -0.000100  1.350540  0.490895   0.470174   9.19  12.325243
# 10        枝江青梗散花 -0.014806  1.167386  2.435687   0.730086   2.11   9.202495
# 11          红莲藕带 -0.233485  1.037284  3.709477   0.596244   3.29   5.907389
# 12       云南生菜(份) -0.000100  1.000001  1.204997   0.263532   2.84  17.980967
# 13            菜心 -0.373519  1.049407  4.302037   0.062728  12.72   4.608342
# 14        小青菜(1) -0.048239  1.732634  0.243295   0.667235   4.40  11.412680
# 15        紫茄子(2) -0.005422  1.000001  2.622818   0.486476  18.00   7.355940
# 16        双孢菇(盒) -0.002679  1.607143  0.083929  -0.080404   3.49  16.728012
# 17        小皱皮(份) -0.038961  1.748252  0.570929   0.759467   2.56  11.930795
# 18            菱角 -0.000100  1.000001  4.760086   0.826860   2.60   3.573166
# 19           竹叶菜 -0.000100  1.284160  0.627256   0.867149   8.39   7.383489
# 20           红薯尖 -0.000100  1.239625  1.802499   0.758666   2.15   5.893866
# 21           螺丝椒 -0.061124  1.000001  3.718573   0.624408   2.21   2.670984
# 22       芜湖青椒(1) -0.004777  1.297625  0.913010   0.615512   4.34   5.775419
# 23         菠菜(份) -0.011071  1.000001  1.743926   0.338417   5.29   4.531606
# 24        海鲜菇(包) -0.000100  1.000001  0.900798  -0.031703   3.12   7.838381
# 25            苋菜 -0.000100  1.237585  0.691662   0.621020   3.43   5.581912
# 26        虫草花(份) -0.008140  2.441861 -2.613954   0.315515   3.63   3.227428
#
#          最大利润         售价
# 0   79.492189  12.582106
# 1   55.602038  13.970056
# 2   44.314818   4.631110
# 3   41.702364   8.526454
# 4   37.213672   7.895239
# 5   32.996809   5.132858
# 6   29.915729   5.370699
# 7   27.661788   5.361190
# 8   27.110572   4.541322
# 9   25.903077  11.291628
# 10  24.039486   4.722279
# 11  22.275636   7.060809
# 12  21.667043   4.044999
# 13  21.273325  17.336265
# 14  21.171541   6.255089
# 15  19.293355  20.622826
# 16  19.126691   4.633393
# 17  18.238501   4.088691
# 18  17.008580   7.360087
# 19  13.432833  10.209307
# 20  12.141931   4.210096
# 21   9.932254   5.928574
# 22   9.003047   5.898856
# 23   7.902796   7.033928
# 24   7.060809   4.020799
# 25   6.135196   4.529121
# 26   0.009758   3.633023
